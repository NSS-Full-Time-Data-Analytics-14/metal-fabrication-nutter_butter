# %%
from sqlalchemy import create_engine, text
import pandas as pd

# %%
database_name = 'metal'    # Fill this in with your lahman database name

connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}"

# %%
query1 = "SELECT * FROM job_operations_2023"

# %%
engine = create_engine(connection_string)

# %%
with engine.connect() as connection:
    job_operations_2023 = pd.read_sql(text(query1), con = connection)

# %% [markdown]
# # *** job_operations_2023

# %%
job_operations_2023.head(3)
# Out:
#        jmo_job_id  jmo_job_assembly_id  jmo_job_operation_id  \
# 0  31816-0001-001                    1                    20
# 1  31872-0001-001                    0                    10
# 2  31872-0001-001                    0                    20
#
#    jmo_operation_type  jmo_added_operation  jmo_prototype_operation  \
# 0                   1                False                    False
# 1                   1                False                    False
# 2                   1                False                    False
#
#   jmo_plant_department_id  jmo_plant_id jmo_work_center_id jmo_process_id  \
# 0                    None           1.0              BRAKE             PB
# 1                    None           1.0              LASER          LASER
# 2                    None           1.0              BRAKE             PB
#
#    ... ujmo_two_man_op ujmo_pfmrelease_date  ujmo_rework_created  \
# 0  ...           False                  NaT                False
# 1  ...           False                  NaT                False
# 2  ...           False                  NaT                False
#
#    ujmo_tooling_needed  ujmo_scheduled_start  ujmo_scheduled_due  \
# 0                False                  None                None
# 1                False                  None                None
# 2                False                  None                None
#
#   ujmo_prod_due_date  ujmo_pfmop_start  ujmo_test_field  ujmo_line_center
# 0               None              None             None              None
# 1               None              None             None              None
# 2               None              None             None              None
#
# [3 rows x 97 columns]

# %%
query2 = "SELECT * FROM job_operations_2024"

# %%
with engine.connect() as connection:
    job_operations_2024 = pd.read_sql(text(query2), con = connection)

# %% [markdown]
# # *** job_operations_2024

# %%
job_operations_2024.head(3)
# Out:
#        jmo_job_id  jmo_job_assembly_id  jmo_job_operation_id  \
# 0  35765-0001-001                    0                    20
# 1  33620-0001-001                    0                    10
# 2  35785-0001-001                    0                    20
#
#    jmo_operation_type  jmo_added_operation  jmo_prototype_operation  \
# 0                   1                False                    False
# 1                   1                False                    False
# 2                   1                False                    False
#
#    jmo_plant_department_id  jmo_plant_id jmo_work_center_id jmo_process_id  \
# 0                      NaN             1               PACK           WRAP
# 1                      NaN             1              LASER          LASER
# 2                      NaN             1               PACK           WRAP
#
#    ... ujmo_two_man_op ujmo_pfmrelease_date  ujmo_rework_created  \
# 0  ...           False                  NaT                False
# 1  ...           False                  NaT                False
# 2  ...           False                  NaT                False
#
#    ujmo_tooling_needed  ujmo_scheduled_start  ujmo_scheduled_due  \
# 0                False                  None                None
# 1                False                  None                None
# 2                False                  None                None
#
#   ujmo_prod_due_date  ujmo_pfmop_start  ujmo_test_field  ujmo_line_center
# 0               None              None             None              None
# 1               None              None             None              None
# 2               None              None             None              None
#
# [3 rows x 97 columns]

# %%
query3 = "SELECT * FROM sales_orders"

# %%
with engine.connect() as connection:
    sales_orders = pd.read_sql(text(query3), con = connection)

# %% [markdown]
# # *** sales_orders

# %%
sales_orders.head(3)
# Out:
#    omp_sales_order_id  omp_plant_id omp_plant_department_id  \
# 0               31876             1                    None
# 1               31877             1                    None
# 2               31878             1                    None
#
#   omp_customer_organization_id  omp_arinvoice_location_id  \
# 0                   M030-MORGO                        NaN
# 1                   M030-MORGO                        NaN
# 2                   M030-MORGO                        NaN
#
#   omp_arinvoice_contact_id  omp_quote_location_id omp_quote_contact_id  \
# 0                    KimHo                    NaN                 None
# 1                    KimHo                    NaN                 None
# 2                    KimHo                    NaN                 None
#
#   omp_ship_organization_id omp_ship_location_id  ...  \
# 0               M030-MORGO                    1  ...
# 1               M030-MORGO                    1  ...
# 2               M030-MORGO                    1  ...
#
#   omp_ups3rd_party_organization_id omp_ups3rd_party_location_id  \
# 0                             None                         None
# 1                             None                         None
# 2                             None                         None
#
#   omp_easy_order_status omp_easy_order_enabled omp_split_percent_total  \
# 0                     0                  False                       0
# 1                     0                  False                       0
# 2                     0                  False                       0
#
#   omp_easy_order_external_status omp_easy_order_paid omp_created_by  \
# 0                            CON               False      bsinclair
# 1                            CON               False      bsinclair
# 2                            CON               False      bsinclair
#
#      omp_created_date uomp_promise_date
# 0 2023-09-12 08:41:55        2023-10-26
# 1 2023-09-12 08:44:53        2023-10-19
# 2 2023-09-12 08:47:07        2023-10-27
#
# [3 rows x 85 columns]

# %%
query4 = "SELECT * FROM sales_order_job_links"

# %%
with engine.connect() as connection:
    sales_order_job_links = pd.read_sql(text(query4), con = connection)

# %% [markdown]
# # *** sales_order_job_links

# %%
sales_order_job_links.head(3)
# Out:
#    omj_sales_order_id  omj_sales_order_line_id  omj_sales_order_job_link_id  \
# 0               31876                        1                            1
# 1               31876                        2                            1
# 2               31877                        1                            1
#
#    omj_link_type  omj_sales_order_delivery_id      omj_job_id  omj_closed  \
# 0              1                            0  31876-0001-001       False
# 1              1                            0  31876-0002-001       False
# 2              1                            0  31877-0001-001       False
#
#   omj_created_by    omj_created_date
# 0      bsinclair 2023-09-12 08:42:50
# 1      bsinclair 2023-09-12 08:43:20
# 2      bsinclair 2023-09-12 08:45:35

# %% [markdown]
# # *** sales_order_and_job_links

# %%
sales_order_and_job_links = pd.merge(sales_orders, sales_order_job_links, 
                               left_on = 'omp_sales_order_id', right_on = 'omj_sales_order_id', 
                               how = 'left')

# %%
sales_order_and_job_links.head(3)
# Out:
#    omp_sales_order_id  omp_plant_id omp_plant_department_id  \
# 0               31876             1                    None
# 1               31876             1                    None
# 2               31877             1                    None
#
#   omp_customer_organization_id  omp_arinvoice_location_id  \
# 0                   M030-MORGO                        NaN
# 1                   M030-MORGO                        NaN
# 2                   M030-MORGO                        NaN
#
#   omp_arinvoice_contact_id  omp_quote_location_id omp_quote_contact_id  \
# 0                    KimHo                    NaN                 None
# 1                    KimHo                    NaN                 None
# 2                    KimHo                    NaN                 None
#
#   omp_ship_organization_id omp_ship_location_id  ... uomp_promise_date  \
# 0               M030-MORGO                    1  ...        2023-10-26
# 1               M030-MORGO                    1  ...        2023-10-26
# 2               M030-MORGO                    1  ...        2023-10-19
#
#   omj_sales_order_id omj_sales_order_line_id omj_sales_order_job_link_id  \
# 0            31876.0                     1.0                         1.0
# 1            31876.0                     2.0                         1.0
# 2            31877.0                     1.0                         1.0
#
#   omj_link_type omj_sales_order_delivery_id      omj_job_id omj_closed  \
# 0           1.0                         0.0  31876-0001-001      False
# 1           1.0                         0.0  31876-0002-001      False
# 2           1.0                         0.0  31877-0001-001      False
#
#   omj_created_by    omj_created_date
# 0      bsinclair 2023-09-12 08:42:50
# 1      bsinclair 2023-09-12 08:43:20
# 2      bsinclair 2023-09-12 08:45:35
#
# [3 rows x 94 columns]

# %%
query5 = "SELECT * FROM jobs"

# %%
with engine.connect() as connection:
    jobs = pd.read_sql(text(query5), con = connection)

# %% [markdown]
# # *** jobs

# %%
jobs.head(3)
# Out:
#        jmp_job_id jmp_plant_department_id  jmp_plant_id  \
# 0  31827-0002-001                    None           1.0
# 1  31827-0003-001                    None           1.0
# 2  31831-0001-001                    None           1.0
#
#   jmp_production_due_date jmp_customer_organization_id jmp_job_date  \
# 0              2023-10-05                   K007-KENWO   2023-09-08
# 1              2023-10-05                   K007-KENWO   2023-09-08
# 2              2023-10-31                   M030-MORGO   2023-09-08
#
#   jmp_part_id jmp_part_revision_id jmp_part_ware_house_location_id  \
# 0   K007-0220                    D                           CHATT
# 1   K007-0820                    0                           CHATT
# 2   M030-0472                    B                           CHATT
#
#   jmp_part_bin_id  ... ujmp_remaining_to_ship ujmp_pfmrelease_date  \
# 0           BIN A  ...                   None  2023-09-20 08:25:48
# 1           BIN A  ...                   None  2023-09-20 09:34:48
# 2           BIN A  ...                   None  2023-10-17 17:40:48
#
#   ujmp_rework_created ujmp_hold_reason  ujmp_hold_owner  ujmp_bomvalidated  \
# 0               False             None                0               True
# 1               False             None                0               True
# 2               False             None                0               True
#
#    ujmp_nest_name  ujmp_qchold  ujmp_qchold_dept ujmp_first_run
# 0         0923148        False                 0          False
# 1         0923127        False                 0          False
# 2          102385        False                 0           True
#
# [3 rows x 69 columns]

# %%
query6 = "SELECT * FROM job_operations_2023"

# %%
with engine.connect() as connection:
    job_operations_2023 = pd.read_sql(text(query6), con = connection)

# %% [markdown]
# # *** job_operations_2023

# %%
job_operations_2023.head(3)
# Out:
#        jmo_job_id  jmo_job_assembly_id  jmo_job_operation_id  \
# 0  31816-0001-001                    1                    20
# 1  31872-0001-001                    0                    10
# 2  31872-0001-001                    0                    20
#
#    jmo_operation_type  jmo_added_operation  jmo_prototype_operation  \
# 0                   1                False                    False
# 1                   1                False                    False
# 2                   1                False                    False
#
#   jmo_plant_department_id  jmo_plant_id jmo_work_center_id jmo_process_id  \
# 0                    None           1.0              BRAKE             PB
# 1                    None           1.0              LASER          LASER
# 2                    None           1.0              BRAKE             PB
#
#    ... ujmo_two_man_op ujmo_pfmrelease_date  ujmo_rework_created  \
# 0  ...           False                  NaT                False
# 1  ...           False                  NaT                False
# 2  ...           False                  NaT                False
#
#    ujmo_tooling_needed  ujmo_scheduled_start  ujmo_scheduled_due  \
# 0                False                  None                None
# 1                False                  None                None
# 2                False                  None                None
#
#   ujmo_prod_due_date  ujmo_pfmop_start  ujmo_test_field  ujmo_line_center
# 0               None              None             None              None
# 1               None              None             None              None
# 2               None              None             None              None
#
# [3 rows x 97 columns]

# %%
jobs_and_operations_2023 = pd.merge(jobs, job_operations_2023, 
                               left_on = 'jmp_job_id', right_on = 'jmo_job_id', 
                               how = 'left')

# %% [markdown]
# # *** jobs_and_operations_2023

# %%
jobs_and_operations_2023.head(3)
# Out:
#        jmp_job_id jmp_plant_department_id  jmp_plant_id  \
# 0  31827-0002-001                    None           1.0
# 1  31827-0002-001                    None           1.0
# 2  31827-0002-001                    None           1.0
#
#   jmp_production_due_date jmp_customer_organization_id jmp_job_date  \
# 0              2023-10-05                   K007-KENWO   2023-09-08
# 1              2023-10-05                   K007-KENWO   2023-09-08
# 2              2023-10-05                   K007-KENWO   2023-09-08
#
#   jmp_part_id jmp_part_revision_id jmp_part_ware_house_location_id  \
# 0   K007-0220                    D                           CHATT
# 1   K007-0220                    D                           CHATT
# 2   K007-0220                    D                           CHATT
#
#   jmp_part_bin_id  ... ujmo_two_man_op ujmo_pfmrelease_date  \
# 0           BIN A  ...           False                  NaT
# 1           BIN A  ...           False                  NaT
# 2           BIN A  ...           False                  NaT
#
#   ujmo_rework_created ujmo_tooling_needed  ujmo_scheduled_start  \
# 0               False               False                  None
# 1               False               False                  None
# 2               False               False                  None
#
#    ujmo_scheduled_due  ujmo_prod_due_date  ujmo_pfmop_start  ujmo_test_field  \
# 0                None                None              None             None
# 1                None                None              None             None
# 2                None                None              None             None
#
#   ujmo_line_center
# 0             None
# 1             None
# 2             None
#
# [3 rows x 166 columns]

# %%
jobs_by_operation_sorder_jlinks = pd.merge(jobs_and_operations_2023, sales_order_and_job_links, 
                               left_on = 'jmp_job_id', right_on = 'omj_job_id', 
                               how = 'left')

# %% [markdown]
# # *** jobs_by_operation_sorder_jlinks

# %%
jobs_by_operation_sorder_jlinks.head(3)
# Out:
#        jmp_job_id jmp_plant_department_id  jmp_plant_id  \
# 0  31827-0002-001                    None           1.0
# 1  31827-0002-001                    None           1.0
# 2  31827-0002-001                    None           1.0
#
#   jmp_production_due_date jmp_customer_organization_id jmp_job_date  \
# 0              2023-10-05                   K007-KENWO   2023-09-08
# 1              2023-10-05                   K007-KENWO   2023-09-08
# 2              2023-10-05                   K007-KENWO   2023-09-08
#
#   jmp_part_id jmp_part_revision_id jmp_part_ware_house_location_id  \
# 0   K007-0220                    D                           CHATT
# 1   K007-0220                    D                           CHATT
# 2   K007-0220                    D                           CHATT
#
#   jmp_part_bin_id  ... uomp_promise_date omj_sales_order_id  \
# 0           BIN A  ...        2023-10-09            31827.0
# 1           BIN A  ...        2023-10-09            31827.0
# 2           BIN A  ...        2023-10-09            31827.0
#
#   omj_sales_order_line_id omj_sales_order_job_link_id  omj_link_type  \
# 0                     2.0                         1.0            1.0
# 1                     2.0                         1.0            1.0
# 2                     2.0                         1.0            1.0
#
#    omj_sales_order_delivery_id      omj_job_id  omj_closed  omj_created_by  \
# 0                          0.0  31827-0002-001       False       bsinclair
# 1                          0.0  31827-0002-001       False       bsinclair
# 2                          0.0  31827-0002-001       False       bsinclair
#
#      omj_created_date
# 0 2023-09-08 12:37:04
# 1 2023-09-08 12:37:04
# 2 2023-09-08 12:37:04
#
# [3 rows x 260 columns]

# %% [markdown]
# # d. Perform a breakdown of customers by operation (as indicated by the jmo_process_short_description in the job_operations_2023 or job_operations_2024 table).

# %% [markdown]
# # *** josj_orgid_operation

# %%
josj_orgid_operation = jobs_by_operation_sorder_jlinks[['jmo_process_short_description','omp_customer_organization_id']]

# %%
josj_orgid_operation.head(3)
# Out:
#                        jmo_process_short_description  \
# 0                                Laser Cut Per Print
# 1  Set-Up Instructions:  Enter program number. Th...
# 2  HOT DIP GALVANIZE PER K3415KT24-04 (3/16'' FORMED
#
#   omp_customer_organization_id
# 0                   K007-KENWO
# 1                   K007-KENWO
# 2                   K007-KENWO

# %%
josj_orgid_operation.loc[josj_orgid_operation.jmo_process_short_description == 'Nan']
# Out:
# Empty DataFrame
# Columns: [jmo_process_short_description, omp_customer_organization_id]
# Index: []

# %%
no_na = josj_orgid_operation.fillna(0)

# %%
no_na2 = no_na.value_counts('jmo_process_short_description')

# %%
no_na3 = pd.DataFrame(no_na2)

# %% [markdown]
# # ANSWER:

# %%
no_na3.head()
# Out:
#                                count
# jmo_process_short_description
# LASER CUTTING                   9329
# MANUAL PRESS BRAKE              6684
# WRAP                            6360
# 0                               6091
# Laser Cut Per Print             3352

# %% [markdown]
# # 3. Inspect the type of operation for each job, as indicated by the jmo_process_short_description in the job_operations_2023 or job_operations_2024 table.
#     a. Are there certain operations, such as welding, which generate more revenue per production hour?
#     b. Are certain operations consistently generating more revenue per production hour than others or has it changed over time?
#     c. Which operations are most frequently associated with the company's top customers? Are they also the ones that are generating the most revenue per production hour?

# %% [markdown]
# ![image.png](attachment:a55a2301-0b2c-4cb9-add9-85edf261c76e.png)

# %% [markdown]
# #     a. Are there certain operations, such as welding, which generate more revenue per production hour?

# %%
query7 = "SELECT * FROM sales_order_lines"

# %%
with engine.connect() as connection:
    sales_order_lines = pd.read_sql(text(query7), con = connection)

# %% [markdown]
# # *** sales_order_lines

# %%
sales_order_lines.head(3)
# Out:
#    oml_sales_order_id  oml_sales_order_line_id oml_part_id oml_org_part_id  \
# 0               34460                        8   M047-0075            None
# 1               34498                        3   M047-0077            None
# 2               31842                        3   M045-0003            None
#
#   oml_part_revision_id oml_unit_of_measure oml_part_group_id  \
# 0                    0                  EA             LVSLS
# 1                    0                  EA             LVSLS
# 2                   00                  EA             LVSLS
#
#          oml_part_short_description oml_org_part_short_description  \
# 0                              9922                           None
# 1                               810                           None
# 2  07018065 BRACKET, HDP20 90 DEG D                           None
#
#                       oml_part_long_description_text  ...  \
# 0                                               None  ...
# 1  LASER CUT 810.DXF MTLWRX SUPPLIED 3/16 HRPO 48...  ...
# 2                   07018065 BRACKET, HDP20 90 DEG D  ...
#
#    oml_deposit_amount_foreign  oml_deposit_created  oml_deposit_credited  \
# 0                         0.0                False                 False
# 1                         0.0                False                 False
# 2                         0.0                False                 False
#
#    oml_documents  oml_avalara_ignore_line  oml_delivery_quantity_total  \
# 0           None                    False                         1600
# 1           None                    False                          120
# 2          14960                    False                           65
#
#    oml_created_by    oml_created_date  oml_easy_order_external_status  \
# 0         kdinger 2024-06-05 08:19:45                             CON
# 1         kdinger 2024-06-10 09:12:13                             CON
# 2       bsinclair 2023-09-08 14:02:20                             CON
#
#    oml_release_number
# 0                None
# 1                None
# 2                None
#
# [3 rows x 66 columns]

# %%
all_sales = sales_order_lines.join(sales_order_and_job_links, on=['oml_sales_order_id'])

# %% [markdown]
# # *** all_sales

# %%
all_sales.head(3)
# Out:
#    oml_sales_order_id  oml_sales_order_line_id oml_part_id oml_org_part_id  \
# 0               34460                        8   M047-0075            None
# 1               34498                        3   M047-0077            None
# 2               31842                        3   M045-0003            None
#
#   oml_part_revision_id oml_unit_of_measure oml_part_group_id  \
# 0                    0                  EA             LVSLS
# 1                    0                  EA             LVSLS
# 2                   00                  EA             LVSLS
#
#          oml_part_short_description oml_org_part_short_description  \
# 0                              9922                           None
# 1                               810                           None
# 2  07018065 BRACKET, HDP20 90 DEG D                           None
#
#                       oml_part_long_description_text  ...  uomp_promise_date  \
# 0                                               None  ...                NaT
# 1  LASER CUT 810.DXF MTLWRX SUPPLIED 3/16 HRPO 48...  ...                NaT
# 2                   07018065 BRACKET, HDP20 90 DEG D  ...                NaT
#
#    omj_sales_order_id  omj_sales_order_line_id  omj_sales_order_job_link_id  \
# 0                 NaN                      NaN                          NaN
# 1                 NaN                      NaN                          NaN
# 2                 NaN                      NaN                          NaN
#
#    omj_link_type  omj_sales_order_delivery_id  omj_job_id  omj_closed  \
# 0            NaN                          NaN         NaN         NaN
# 1            NaN                          NaN         NaN         NaN
# 2            NaN                          NaN         NaN         NaN
#
#    omj_created_by  omj_created_date
# 0             NaN               NaT
# 1             NaN               NaT
# 2             NaN               NaT
#
# [3 rows x 160 columns]

# %% [markdown]
# ![image.png](attachment:c3056c7c-3f98-4080-8865-74c782a0e341.png)

# %% [markdown]
# # *** job_operations_2023

# %%
job_operations_2023.head(3)
# Out:
#        jmo_job_id  jmo_job_assembly_id  jmo_job_operation_id  \
# 0  31816-0001-001                    1                    20
# 1  31872-0001-001                    0                    10
# 2  31872-0001-001                    0                    20
#
#    jmo_operation_type  jmo_added_operation  jmo_prototype_operation  \
# 0                   1                False                    False
# 1                   1                False                    False
# 2                   1                False                    False
#
#   jmo_plant_department_id  jmo_plant_id jmo_work_center_id jmo_process_id  \
# 0                    None           1.0              BRAKE             PB
# 1                    None           1.0              LASER          LASER
# 2                    None           1.0              BRAKE             PB
#
#    ... ujmo_two_man_op ujmo_pfmrelease_date  ujmo_rework_created  \
# 0  ...           False                  NaT                False
# 1  ...           False                  NaT                False
# 2  ...           False                  NaT                False
#
#    ujmo_tooling_needed  ujmo_scheduled_start  ujmo_scheduled_due  \
# 0                False                  None                None
# 1                False                  None                None
# 2                False                  None                None
#
#   ujmo_prod_due_date  ujmo_pfmop_start  ujmo_test_field  ujmo_line_center
# 0               None              None             None              None
# 1               None              None             None              None
# 2               None              None             None              None
#
# [3 rows x 97 columns]

# %%
job_operations_2024.head(3)
# Out:
#        jmo_job_id  jmo_job_assembly_id  jmo_job_operation_id  \
# 0  35765-0001-001                    0                    20
# 1  33620-0001-001                    0                    10
# 2  35785-0001-001                    0                    20
#
#    jmo_operation_type  jmo_added_operation  jmo_prototype_operation  \
# 0                   1                False                    False
# 1                   1                False                    False
# 2                   1                False                    False
#
#    jmo_plant_department_id  jmo_plant_id jmo_work_center_id jmo_process_id  \
# 0                      NaN             1               PACK           WRAP
# 1                      NaN             1              LASER          LASER
# 2                      NaN             1               PACK           WRAP
#
#    ... ujmo_two_man_op ujmo_pfmrelease_date  ujmo_rework_created  \
# 0  ...           False                  NaT                False
# 1  ...           False                  NaT                False
# 2  ...           False                  NaT                False
#
#    ujmo_tooling_needed  ujmo_scheduled_start  ujmo_scheduled_due  \
# 0                False                  None                None
# 1                False                  None                None
# 2                False                  None                None
#
#   ujmo_prod_due_date  ujmo_pfmop_start  ujmo_test_field  ujmo_line_center
# 0               None              None             None              None
# 1               None              None             None              None
# 2               None              None             None              None
#
# [3 rows x 97 columns]

# %%
all_sales.head(3)
# Out:
#    oml_sales_order_id  oml_sales_order_line_id oml_part_id oml_org_part_id  \
# 0               34460                        8   M047-0075            None
# 1               34498                        3   M047-0077            None
# 2               31842                        3   M045-0003            None
#
#   oml_part_revision_id oml_unit_of_measure oml_part_group_id  \
# 0                    0                  EA             LVSLS
# 1                    0                  EA             LVSLS
# 2                   00                  EA             LVSLS
#
#          oml_part_short_description oml_org_part_short_description  \
# 0                              9922                           None
# 1                               810                           None
# 2  07018065 BRACKET, HDP20 90 DEG D                           None
#
#                       oml_part_long_description_text  ...  uomp_promise_date  \
# 0                                               None  ...                NaT
# 1  LASER CUT 810.DXF MTLWRX SUPPLIED 3/16 HRPO 48...  ...                NaT
# 2                   07018065 BRACKET, HDP20 90 DEG D  ...                NaT
#
#    omj_sales_order_id  omj_sales_order_line_id  omj_sales_order_job_link_id  \
# 0                 NaN                      NaN                          NaN
# 1                 NaN                      NaN                          NaN
# 2                 NaN                      NaN                          NaN
#
#    omj_link_type  omj_sales_order_delivery_id  omj_job_id  omj_closed  \
# 0            NaN                          NaN         NaN         NaN
# 1            NaN                          NaN         NaN         NaN
# 2            NaN                          NaN         NaN         NaN
#
#    omj_created_by  omj_created_date
# 0             NaN               NaT
# 1             NaN               NaT
# 2             NaN               NaT
#
# [3 rows x 160 columns]

# %%
sales_order_and_job_links.head(3)
# Out:
#    omp_sales_order_id  omp_plant_id omp_plant_department_id  \
# 0               31876             1                    None
# 1               31876             1                    None
# 2               31877             1                    None
#
#   omp_customer_organization_id  omp_arinvoice_location_id  \
# 0                   M030-MORGO                        NaN
# 1                   M030-MORGO                        NaN
# 2                   M030-MORGO                        NaN
#
#   omp_arinvoice_contact_id  omp_quote_location_id omp_quote_contact_id  \
# 0                    KimHo                    NaN                 None
# 1                    KimHo                    NaN                 None
# 2                    KimHo                    NaN                 None
#
#   omp_ship_organization_id omp_ship_location_id  ... uomp_promise_date  \
# 0               M030-MORGO                    1  ...        2023-10-26
# 1               M030-MORGO                    1  ...        2023-10-26
# 2               M030-MORGO                    1  ...        2023-10-19
#
#   omj_sales_order_id omj_sales_order_line_id omj_sales_order_job_link_id  \
# 0            31876.0                     1.0                         1.0
# 1            31876.0                     2.0                         1.0
# 2            31877.0                     1.0                         1.0
#
#   omj_link_type omj_sales_order_delivery_id      omj_job_id omj_closed  \
# 0           1.0                         0.0  31876-0001-001      False
# 1           1.0                         0.0  31876-0002-001      False
# 2           1.0                         0.0  31877-0001-001      False
#
#   omj_created_by    omj_created_date
# 0      bsinclair 2023-09-12 08:42:50
# 1      bsinclair 2023-09-12 08:43:20
# 2      bsinclair 2023-09-12 08:45:35
#
# [3 rows x 94 columns]

# %%
sales_orders.head(3)
# Out:
#    omp_sales_order_id  omp_plant_id omp_plant_department_id  \
# 0               31876             1                    None
# 1               31877             1                    None
# 2               31878             1                    None
#
#   omp_customer_organization_id  omp_arinvoice_location_id  \
# 0                   M030-MORGO                        NaN
# 1                   M030-MORGO                        NaN
# 2                   M030-MORGO                        NaN
#
#   omp_arinvoice_contact_id  omp_quote_location_id omp_quote_contact_id  \
# 0                    KimHo                    NaN                 None
# 1                    KimHo                    NaN                 None
# 2                    KimHo                    NaN                 None
#
#   omp_ship_organization_id omp_ship_location_id  ...  \
# 0               M030-MORGO                    1  ...
# 1               M030-MORGO                    1  ...
# 2               M030-MORGO                    1  ...
#
#   omp_ups3rd_party_organization_id omp_ups3rd_party_location_id  \
# 0                             None                         None
# 1                             None                         None
# 2                             None                         None
#
#   omp_easy_order_status omp_easy_order_enabled omp_split_percent_total  \
# 0                     0                  False                       0
# 1                     0                  False                       0
# 2                     0                  False                       0
#
#   omp_easy_order_external_status omp_easy_order_paid omp_created_by  \
# 0                            CON               False      bsinclair
# 1                            CON               False      bsinclair
# 2                            CON               False      bsinclair
#
#      omp_created_date uomp_promise_date
# 0 2023-09-12 08:41:55        2023-10-26
# 1 2023-09-12 08:44:53        2023-10-19
# 2 2023-09-12 08:47:07        2023-10-27
#
# [3 rows x 85 columns]

# %%
sales_order_job_links.head(3)
# Out:
#    omj_sales_order_id  omj_sales_order_line_id  omj_sales_order_job_link_id  \
# 0               31876                        1                            1
# 1               31876                        2                            1
# 2               31877                        1                            1
#
#    omj_link_type  omj_sales_order_delivery_id      omj_job_id  omj_closed  \
# 0              1                            0  31876-0001-001       False
# 1              1                            0  31876-0002-001       False
# 2              1                            0  31877-0001-001       False
#
#   omj_created_by    omj_created_date
# 0      bsinclair 2023-09-12 08:42:50
# 1      bsinclair 2023-09-12 08:43:20
# 2      bsinclair 2023-09-12 08:45:35

# %%
jobs.head(3)
# Out:
#        jmp_job_id jmp_plant_department_id  jmp_plant_id  \
# 0  31827-0002-001                    None           1.0
# 1  31827-0003-001                    None           1.0
# 2  31831-0001-001                    None           1.0
#
#   jmp_production_due_date jmp_customer_organization_id jmp_job_date  \
# 0              2023-10-05                   K007-KENWO   2023-09-08
# 1              2023-10-05                   K007-KENWO   2023-09-08
# 2              2023-10-31                   M030-MORGO   2023-09-08
#
#   jmp_part_id jmp_part_revision_id jmp_part_ware_house_location_id  \
# 0   K007-0220                    D                           CHATT
# 1   K007-0820                    0                           CHATT
# 2   M030-0472                    B                           CHATT
#
#   jmp_part_bin_id  ... ujmp_remaining_to_ship ujmp_pfmrelease_date  \
# 0           BIN A  ...                   None  2023-09-20 08:25:48
# 1           BIN A  ...                   None  2023-09-20 09:34:48
# 2           BIN A  ...                   None  2023-10-17 17:40:48
#
#   ujmp_rework_created ujmp_hold_reason  ujmp_hold_owner  ujmp_bomvalidated  \
# 0               False             None                0               True
# 1               False             None                0               True
# 2               False             None                0               True
#
#    ujmp_nest_name  ujmp_qchold  ujmp_qchold_dept ujmp_first_run
# 0         0923148        False                 0          False
# 1         0923127        False                 0          False
# 2          102385        False                 0           True
#
# [3 rows x 69 columns]

# %%
jobs_and_operations_2023.head(3)
# Out:
#        jmp_job_id jmp_plant_department_id  jmp_plant_id  \
# 0  31827-0002-001                    None           1.0
# 1  31827-0002-001                    None           1.0
# 2  31827-0002-001                    None           1.0
#
#   jmp_production_due_date jmp_customer_organization_id jmp_job_date  \
# 0              2023-10-05                   K007-KENWO   2023-09-08
# 1              2023-10-05                   K007-KENWO   2023-09-08
# 2              2023-10-05                   K007-KENWO   2023-09-08
#
#   jmp_part_id jmp_part_revision_id jmp_part_ware_house_location_id  \
# 0   K007-0220                    D                           CHATT
# 1   K007-0220                    D                           CHATT
# 2   K007-0220                    D                           CHATT
#
#   jmp_part_bin_id  ... ujmo_two_man_op ujmo_pfmrelease_date  \
# 0           BIN A  ...           False                  NaT
# 1           BIN A  ...           False                  NaT
# 2           BIN A  ...           False                  NaT
#
#   ujmo_rework_created ujmo_tooling_needed  ujmo_scheduled_start  \
# 0               False               False                  None
# 1               False               False                  None
# 2               False               False                  None
#
#    ujmo_scheduled_due  ujmo_prod_due_date  ujmo_pfmop_start  ujmo_test_field  \
# 0                None                None              None             None
# 1                None                None              None             None
# 2                None                None              None             None
#
#   ujmo_line_center
# 0             None
# 1             None
# 2             None
#
# [3 rows x 166 columns]

# %%
josj_orgid_operation.head(3)
# Out:
#                        jmo_process_short_description  \
# 0                                Laser Cut Per Print
# 1  Set-Up Instructions:  Enter program number. Th...
# 2  HOT DIP GALVANIZE PER K3415KT24-04 (3/16'' FORMED
#
#   omp_customer_organization_id
# 0                   K007-KENWO
# 1                   K007-KENWO
# 2                   K007-KENWO
