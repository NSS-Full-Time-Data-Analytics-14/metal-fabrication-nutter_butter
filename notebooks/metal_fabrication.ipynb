# %%
from sqlalchemy import create_engine, text
import pandas as pd

# %%
database_name = 'metal'    # Fill this in with your lahman database name

connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}"

# %%
query1 = "SELECT * FROM job_operations_2023"

# %%
engine = create_engine(connection_string)

# %%
with engine.connect() as connection:
    job_operations_2023 = pd.read_sql(text(query1), con = connection)

# %% [markdown]
# # *** job_operations_2023

# %%
job_operations_2023.head(3)
# Out:
#        jmo_job_id  jmo_job_assembly_id  jmo_job_operation_id  \
# 0  31816-0001-001                    1                    20
# 1  31872-0001-001                    0                    10
# 2  31872-0001-001                    0                    20
#
#    jmo_operation_type  jmo_added_operation  jmo_prototype_operation  \
# 0                   1                False                    False
# 1                   1                False                    False
# 2                   1                False                    False
#
#   jmo_plant_department_id  jmo_plant_id jmo_work_center_id jmo_process_id  \
# 0                    None           1.0              BRAKE             PB
# 1                    None           1.0              LASER          LASER
# 2                    None           1.0              BRAKE             PB
#
#    ... ujmo_two_man_op ujmo_pfmrelease_date  ujmo_rework_created  \
# 0  ...           False                  NaT                False
# ...

# %%
query2 = "SELECT * FROM job_operations_2024"

# %%
with engine.connect() as connection:
    job_operations_2024 = pd.read_sql(text(query2), con = connection)

# %% [markdown]
# # *** job_operations_2024

# %%
job_operations_2024.head(3)
# Out:
#        jmo_job_id  jmo_job_assembly_id  jmo_job_operation_id  \
# 0  35765-0001-001                    0                    20
# 1  33620-0001-001                    0                    10
# 2  35785-0001-001                    0                    20
#
#    jmo_operation_type  jmo_added_operation  jmo_prototype_operation  \
# 0                   1                False                    False
# 1                   1                False                    False
# 2                   1                False                    False
#
#    jmo_plant_department_id  jmo_plant_id jmo_work_center_id jmo_process_id  \
# 0                      NaN             1               PACK           WRAP
# 1                      NaN             1              LASER          LASER
# 2                      NaN             1               PACK           WRAP
#
#    ... ujmo_two_man_op ujmo_pfmrelease_date  ujmo_rework_created  \
# 0  ...           False                  NaT                False
# ...

# %%
query3 = "SELECT * FROM sales_orders"

# %%
with engine.connect() as connection:
    sales_orders = pd.read_sql(text(query3), con = connection)

# %% [markdown]
# # *** sales_orders

# %%
sales_orders.head(3)
# Out:
#    omp_sales_order_id  omp_plant_id omp_plant_department_id  \
# 0               31876             1                    None
# 1               31877             1                    None
# 2               31878             1                    None
#
#   omp_customer_organization_id  omp_arinvoice_location_id  \
# 0                   M030-MORGO                        NaN
# 1                   M030-MORGO                        NaN
# 2                   M030-MORGO                        NaN
#
#   omp_arinvoice_contact_id  omp_quote_location_id omp_quote_contact_id  \
# 0                    KimHo                    NaN                 None
# 1                    KimHo                    NaN                 None
# 2                    KimHo                    NaN                 None
#
#   omp_ship_organization_id omp_ship_location_id  ...  \
# 0               M030-MORGO                    1  ...
# 1               M030-MORGO                    1  ...
# ...

# %%
query4 = "SELECT * FROM sales_order_job_links"

# %%
with engine.connect() as connection:
    sales_order_job_links = pd.read_sql(text(query4), con = connection)

# %% [markdown]
# # *** sales_order_job_links

# %%
sales_order_job_links.head(3)
# Out:
#    omj_sales_order_id  omj_sales_order_line_id  omj_sales_order_job_link_id  \
# 0               31876                        1                            1
# 1               31876                        2                            1
# 2               31877                        1                            1
#
#    omj_link_type  omj_sales_order_delivery_id      omj_job_id  omj_closed  \
# 0              1                            0  31876-0001-001       False
# 1              1                            0  31876-0002-001       False
# 2              1                            0  31877-0001-001       False
#
#   omj_created_by    omj_created_date
# 0      bsinclair 2023-09-12 08:42:50
# 1      bsinclair 2023-09-12 08:43:20
# 2      bsinclair 2023-09-12 08:45:35

# %% [markdown]
# # *** sales_order_and_job_links

# %%
sales_order_and_job_links = pd.merge(sales_orders, sales_order_job_links, 
                               left_on = 'omp_sales_order_id', right_on = 'omj_sales_order_id', 
                               how = 'left')

# %%
sales_order_and_job_links.head(3)
# Out:
#    omp_sales_order_id  omp_plant_id omp_plant_department_id  \
# 0               31876             1                    None
# 1               31876             1                    None
# 2               31877             1                    None
#
#   omp_customer_organization_id  omp_arinvoice_location_id  \
# 0                   M030-MORGO                        NaN
# 1                   M030-MORGO                        NaN
# 2                   M030-MORGO                        NaN
#
#   omp_arinvoice_contact_id  omp_quote_location_id omp_quote_contact_id  \
# 0                    KimHo                    NaN                 None
# 1                    KimHo                    NaN                 None
# 2                    KimHo                    NaN                 None
#
#   omp_ship_organization_id omp_ship_location_id  ... uomp_promise_date  \
# 0               M030-MORGO                    1  ...        2023-10-26
# ...

# %%
query5 = "SELECT * FROM jobs"

# %%
with engine.connect() as connection:
    jobs1 = pd.read_sql(text(query5), con = connection)

# %% [markdown]
# # *** jobs1

# %%
jobs1
# Out:
#            jmp_job_id jmp_plant_department_id  jmp_plant_id  \
# 0      31827-0002-001                    None           1.0
# 1      31827-0003-001                    None           1.0
# 2      31831-0001-001                    None           1.0
# 3      31832-0001-001                    None           1.0
# 4      31833-0001-001                    None           1.0
# ...               ...                     ...           ...
# 14810  35815-0001-001                    None           1.0
# 14811  35819-0001-001                    None           1.0
# 14812  35819-0002-001                    None           1.0
# 14813  35820-0001-001                    None           1.0
# 14814  35821-0001-001                    None           1.0
#
#       jmp_production_due_date jmp_customer_organization_id jmp_job_date  \
# 0                  2023-10-05                   K007-KENWO   2023-09-08
# 1                  2023-10-05                   K007-KENWO   2023-09-08
# ...

# %%
query6 = "SELECT * FROM job_operations_2023"

# %%
with engine.connect() as connection:
    job_operations_2023 = pd.read_sql(text(query6), con = connection)

# %% [markdown]
# # *** job_operations_2023

# %%
job_operations_2023.head(3)
# Out:
#        jmo_job_id  jmo_job_assembly_id  jmo_job_operation_id  \
# 0  31816-0001-001                    1                    20
# 1  31872-0001-001                    0                    10
# 2  31872-0001-001                    0                    20
#
#    jmo_operation_type  jmo_added_operation  jmo_prototype_operation  \
# 0                   1                False                    False
# 1                   1                False                    False
# 2                   1                False                    False
#
#   jmo_plant_department_id  jmo_plant_id jmo_work_center_id jmo_process_id  \
# 0                    None           1.0              BRAKE             PB
# 1                    None           1.0              LASER          LASER
# 2                    None           1.0              BRAKE             PB
#
#    ... ujmo_two_man_op ujmo_pfmrelease_date  ujmo_rework_created  \
# 0  ...           False                  NaT                False
# ...

# %%
jobs_and_operations_2023 = pd.merge(jobs, job_operations_2023, 
                               left_on = 'jmp_job_id', right_on = 'jmo_job_id', 
                               how = 'left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 jobs_and_operations_2023 = pd.merge(jobs, job_operations_2023,
#       2                                left_on = 'jmp_job_id', right_on = 'jmo_job_id',
#       3                                how = 'left')
#
# NameError: name 'jobs' is not defined

# %% [markdown]
# # *** jobs_and_operations_2023

# %%
jobs_and_operations_2023.head(3)

# %%
jobs_by_operation_sorder_jlinks = pd.merge(jobs_and_operations_2023, sales_order_and_job_links, 
                               left_on = 'jmp_job_id', right_on = 'omj_job_id', 
                               how = 'left')

# %% [markdown]
# # *** jobs_by_operation_sorder_jlinks

# %%
jobs_by_operation_sorder_jlinks.head(3)

# %% [markdown]
# # d. Perform a breakdown of customers by operation (as indicated by the jmo_process_short_description in the job_operations_2023 or job_operations_2024 table).

# %% [markdown]
# # *** josj_orgid_operation

# %%
josj_orgid_operation = jobs_by_operation_sorder_jlinks[['jmo_process_short_description','omp_customer_organization_id']]

# %%
josj_orgid_operation.head(3)

# %%
josj_orgid_operation.loc[josj_orgid_operation.jmo_process_short_description == 'Nan']

# %%
no_na = josj_orgid_operation.fillna(0)

# %%
no_na

# %%
no_na2 = no_na.value_counts('jmo_process_short_description')

# %%
no_na3 = pd.DataFrame(no_na2)

# %% [markdown]
# # ANSWER:

# %%
no_na3.head()

# %% [markdown]
# # 3. Inspect the type of operation for each job, as indicated by the jmo_process_short_description in the job_operations_2023 or job_operations_2024 table.
#     a. Are there certain operations, such as welding, which generate more revenue per production hour?
#     b. Are certain operations consistently generating more revenue per production hour than others or has it changed over time?
#     c. Which operations are most frequently associated with the company's top customers? Are they also the ones that are generating the most revenue per production hour?

# %% [markdown]
# #     a. Are there certain operations, such as welding, which generate more revenue per production hour?

# %%
query7 = "SELECT jmo_process_short_description,jmo_process_id,jmo_actual_production_hours,jmo_estimated_production_hours,jmo_completed_production_hours FROM job_operations_2023"

# %%
with engine.connect() as connection:
    sales_order_lines = pd.read_sql(text(query7), con = connection)

# %% [markdown]
# # *** sales_order_lines

# %%
sales_order_lines.head(1)

# %%
sales_order_lines_weld_only = sales_order_lines.loc[sales_order_lines['jmo_process_id'] == 'WELD']

# %% [markdown]
# # *** sales_order_lines_weld_only

# %%
sales_order_lines_weld_only.head(1)

# %%
job_operations_2023

# %%
sales_order_lines_weld_only.rename(columns={'jmo_process_short_description' : 'process_short_description'}, inplace=True)

# %%
sales_order_lines_weld_only.rename(columns={'jmo_process_id' : 'process_id'}, inplace=True)

# %%
sales_order_lines_weld_only.rename(columns={'jmo_actual_production_hours' : 'actual_production_hours','jmo_estimated_production_hours' : 'estimated_production_hours','jmo_completed_production_hours' : 'completed_production_hours'}, inplace=True)

# %%
sales_order_lines_weld_only.head(3)

# %%
# total revenue

# %% [markdown]
# SELECT oml_sales_order_id,oml_part_id,oml_order_quantity,oml_full_unit_price_base,oml_full_extended_price_base FROM sales_order_lines

# %% [markdown]
# query7 = "SELECT jmo_process_short_description,jmo_process_id,jmo_actual_production_hours,jmo_estimated_production_hours,jmo_completed_production_hours FROM job_operations_2023"

# %%
query8 = "SELECT oml_sales_order_id,oml_part_id,oml_order_quantity,oml_full_unit_price_base,oml_full_extended_price_base FROM sales_order_lines"

# %%
with engine.connect() as connection:
    job_operations_2023 = pd.read_sql(text(query8), con = connection)

# %%
job_operations_2023

# %%
job_operations_2023

# %% [markdown]
# # create tables a list with all relevant ID's for each table.

# %%
query10 = "SELECT * FROM part_assemblies"

# %%
with engine.connect() as connection:
    part_assemblies = pd.read_sql(text(query10), con = connection)

# %%
columns = part_assemblies.columns

# %%
columns

# %%
   my_list = ['ima_method_id', 'ima_method_revision_id', 'ima_method_assembly_id',
       'ima_level', 'ima_parent_assembly_id', 'ima_part_id',
       'ima_part_revision_id', 'ima_unit_of_measure',
       'ima_part_short_description', 'ima_part_long_description_text',
       'ima_use_method', 'ima_source_method_id']
   my_tuple = tuple(my_list)

# %%
# took only the names with _id and turned the list into data frame.

part_assemblies = pd.DataFrame(my_list)

# %%
part_assemblies

# %%
part_assemblies.sort_values(0)

# %%
part_assemblies.rename(columns={0: 'part_assemblies'}, inplace=True)

# %%
part_assemblies

# %%
part_assemblies.sort_values('part_assemblies')

# %%
query1 = "SELECT * FROM sales_orders"

# %%
engine = create_engine(connection_string)

# %%
with engine.connect() as connection:
    sales_orders = pd.read_sql(text(query1), con = connection)

# %%
sales_orders.head(3)

# %%
sales_orders.to_csv('sales_orders2.csv', index=False)

# %% [markdown]
# # original code that caused multiple repeats.
#
# query1 = '''WITH revenue_and_hours AS (SELECT
# jmp_part_id,
# sum(omp_full_order_subtotal_base) AS total_revenue_earned,
# sum(jmo_actual_production_hours) AS total_production_hours,
# FROM sales_orders
# LEFT JOIN sales_order_job_links ON sales_orders.omp_sales_order_id  = sales_order_job_links.omj_sales_order_id
# LEFT JOIN jobs ON sales_order_job_links.omj_job_id = jobs.jmp_job_id
# LEFT JOIN job_operations_2023 ON job_operations_2023.jmo_job_id = jobs.jmp_job_id
# WHERE jmp_production_complete = True
# GROUP BY jmp_part_id
# ORDER BY total_revenue_earned DESC)
# SELECT
# jmp_part_id,
# CAST(total_revenue_earned AS INTEGER),
# CAST(total_production_hours AS INTEGER),
# total_revenue_earned/NULLIF(total_production_hours, 0) AS revenue_per_hour
# FROM revenue_and_hours
# WHERE total_production_hours > '0'
# ORDER BY revenue_per_hour DESC NULLS LAST'''

# %% [markdown]
# engine = create_engine(connection_string)

# %% [markdown]
# with engine.connect() as connection:
#     test1 = pd.read_sql(text(query1), con = connection)

# %% [markdown]
# parts_revenue = test1[['jmp_part_id','total_revenue_earned','total_production_hours']]

# %% [markdown]
# parts_by_revenue = parts_revenue.sort_values('total_revenue_earned', ascending = False).reset_index(drop = True)

# %% [markdown]
# # *** parts_by_revenue

# %% [markdown]
# parts_by_revenue.head(10)

# %% [markdown]
# parts_by_revenue['revenue_per_hour'] = parts_by_revenue['total_revenue_earned']/parts_by_revenue['total_production_hours']

# %% [markdown]
# # convert to money
#
# parts_by_revenue['revenue_per_hour'] = parts_by_revenue['revenue_per_hour'].apply(lambda x: f"${x:,.2f}")

# %% [markdown]
# # convert to money
#
# parts_by_revenue['total_revenue_earned'] = parts_by_revenue['total_revenue_earned'].apply(lambda x: f"${x:,.2f}")

# %% [markdown]
# top_ten_revenue_earning_part = parts_by_revenue.sort_values('total_revenue_earned', ascending = False)

# %% [markdown]
# top_ten_revenue_earning_part.head(3)

# %% [markdown]
# top_ten_revenue_earning_part['total_revenue_earned'] = top_ten_revenue_earning_part['total_revenue_earned'].apply(lambda x: f"${x:,.2f}")

# %% [markdown]
# top_ten_revenue_earning_part['revenue_per_hour'] = top_ten_revenue_earning_part['revenue_per_hour'].apply(lambda x: f"${x:,.2f}")

# %% [markdown]
# top_ten_revenue_earning_part.head(10)

# %% [markdown]
# parts_by_revenue.fillna(0, inplace=True)

# %% [markdown]
# # *** parts_by_revenue_no_zero

# %% [markdown]
# parts_by_revenue_no_zero = parts_by_revenue.loc[parts_by_revenue['total_production_hours'] != 0]

# %% [markdown]
# parts_by_revenue_no_zero.head(3)

# %% [markdown]
# test1 = parts_by_revenue_no_zero.sort_values('revenue_per_hour', ascending = False)

# %% [markdown]
# test1.head(10)

# %% [markdown]
# test1['revenue_per_hour'] = test1['revenue_per_hour'].apply(lambda x: f"${x:,.2f}")

# %% [markdown]
# test1['total_revenue_earned'] = test1['total_revenue_earned'].apply(lambda x: f"${x:,.2f}")

# %% [markdown]
# test1

# %% [raw]
# How much was the revenue per hour by part?
# What part performed the best?
# How much did the company make per hour for this part?

# %%
pieces = {"x": jobs_and_operations_2023, "y": job_operations_2024}

# %%
jobs_and_operations_all = pd.concat(pieces)

# %% [markdown]
# # *** jobs_and_operations_all

# %%
jobs_and_operations_all.head(3)

# %%
all_jobs = pd.merge(jobs_and_operations_all, jobs,  how='left', left_on=['jmp_job_id','jmp_part_id'], right_on = ['jmp_job_id','jmp_part_id'])

# %% [markdown]
# # *** all_jobs

# %%
all_jobs.head(3)

# %%
sales_order_and_job_links.head(3)

# %% [markdown]
# ![image.png](attachment:47b16935-ee64-4cf4-8e99-870531ef463c.png)

# %%
test = pd.merge(all_jobs, sales_order_and_job_links,how='left', left_on='jmp_job_id', right_on = 'omj_job_id')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 test = pd.merge(all_jobs, sales_order_and_job_links,how='left', left_on='jmp_job_id', right_on = 'omj_job_id')
#
# NameError: name 'all_jobs' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 test
#
# NameError: name 'test' is not defined

# %%
top_revenue = sales_orders[['omp_sales_order_id','omp_full_order_subtotal_base']]

# %%
top_ten_revenue = top_revenue.sort_values('omp_full_order_subtotal_base', ascending = False)

# %%
top_ten_revenue['omp_full_order_subtotal_base'] = top_ten_revenue['omp_full_order_subtotal_base'].apply(lambda x: f"${x:,.2f}")

# %%
top_ten_revenue = top_ten_revenue.reset_index(drop = True)

# %%
top_ten_revenue_10 = top_ten_revenue.head(10)

# %%
top_ten_revenue_10

# %%
jobs1[['jmp_customer_organization_id']]

# %% [markdown]
# jobs_and_sales_order_and_job_links = pd.merge(sales_order_and_job_links, jobs,  how='left', left_on= 'omj_job_id', right_on = 'jmp_job_id')

# %% [markdown]
# ![image.png](attachment:c3056c7c-3f98-4080-8865-74c782a0e341.png)

# %% [markdown]
# # *** job_operations_2023

# %%
job_operations_2023.head(1)

# %%
job_operations_2023.columns

# %%
job_operations_2024.head(1)

# %%
sales_order_and_job_links.head(1)

# %%
sales_orders.head(1)

# %%
sales_order_lines_weld_only.head(1)

# %%
sales_order_job_links.head(1)

# %%
jobs.head(1)

# %%
jobs_and_operations_2023.head(1)

# %%
jobs_and_operations_all.head(3)

# %%
josj_orgid_operation.head(1)
